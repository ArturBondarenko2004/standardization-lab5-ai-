# %%
# !pip install -q openai==1.0.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.6 MB/s eta 0:00:00

# %%
# !pip install --upgrade openai

# %%
mobile_app_project = """
Тема: Розробка мобільного застосунку «Розумний будинок».
Мета: Мета дипломної роботи полягає в розробці мобільного застосунку "Розумний Будинок" є створення інтегрованого рішення, яке дозволить користувачам ефективно, зручно та ощадливо керувати всіма пристроями свого дому, що полягає в наданні інтуїтивного інтерфейсу для контролю та моніторингу різних пристроїв і систем.
Завдання:
-	Розробити мобільний застосунок зі зручним та інтуїтивно зрозумілим інтерфейсом для управління пристроями та системами, забезпечивши зручну навігацію та доступ до основних функцій застосунку.
-	Розробити архітектуру системи, що включає мобільний додаток, серверну частину та інтеграцію з пристроями IoT.
-	Провести інтеграцію з хмарними сервісами для інформації про пристрої системи задля збору аналітики, що дозволить керувати будинком ефективніше та ощадливіше.
-	Забезпечити шифрування даних як і клієнта, так і інформації про мешкання та захист від несанкціонованого доступу.
-	Для того, щоб застосунок був не типовим рішенням на ринку, буде розроблено сценарії автоматизації для виконання дій у відповідь на певні події(наприклад, ввімкнення світла різної яскравості, при розпізнаванні обличчя), завдяки інтеграції API та модулів штучного інтелекту  в застосунок.
Предмет:
Технології та методи створення мобільного додатку для управління системами "Розумний Будинок".
Об’єкт:
Система "Розумний Будинок" та її складові компоненти, такі як електротехніка, системи безпеки, камери спостереження та інші пристрої.
Актуальність:
В умовах глобальних змін клімату, зростання цін на енергоносії та зростання рівня злочинності і природних катастроф, питання енергоефективності та безпеки стають все більш актуальними. Застосунок  дозволить не лише оптимізувати споживання енергії та автоматизувати роботу пристроїв, значно знижуючи витрати на комунальні послуги і забезпечуючи економію коштів користувачам, а й завдяки інтеграції API та модулів штучного інтелекту зможе визначити не типову поведінку людини та визвати екстрену службу, що й додає  додатковий рівень безпеки, забезпечуючи спокій та впевненість.
Практичне значення:
Застосунок дозволяє ефективно керувати енергоспоживанням та забезпечує безпеку будинку через інтеграцію з камерами спостереження та датчиками безпеки. Також надає зручність та комфорт користувачам завдяки автоматизації рутинних завдань та можливості віддаленого керування.
Аналоги:
Google Home - це розважально-інформаційний додаток та голосовий помічник, розроблений Google. Він дозволяє користувачам керувати підключеними пристроями в будинку, такими як розетки, освітлення, термостати, а також відтворювати музику, слухати новини, здійснювати пошук в Інтернеті та інше. Основним інтерфейсом для взаємодії є голосові команди, але також доступний мобільний додаток для керування.
Apple HomeKit - це платформа для розумного дому, розроблена Apple Inc. Вона дозволяє підключати та керувати побутовими пристроями, такими як освітлення, термостати, дверні замки, камери безпеки та багато іншого, за допомогою iPhone, iPad або голосових команд за допомогою Siri. Apple HomeKit забезпечує високий рівень безпеки та конфіденційності даних, а також підтримує автоматизаційні сценарії для спрощення щоденних завдань вдома.
Потенційний стек:
Мобільний застосунок, що буде створюватись для Android, за допомогою середовища розробки Android Studio та мови програмування Java.
Мобільний застосунок, що буде створюватись для IOS, за допомогою середовища розробки Xcode та мови програмування Swift.
Реалізація обміну даними між мобільним додатком та сервером буде реалізована за допомогою за допомогою REST API.
Бекенд буде реалізований за допомогою Python з фреймворком Django.
Інтеграція з штучним інтелектом буде реалізована з використанням Використання API та бібліотек машинного навчання, таких як TensorFlow або PyTorch, для аналізу даних з відеокамер та визначення нетипової поведінки користувачів.
Використання інструменту моніторингу та логування  Grafana, для відстеження працездатності та виявлення проблем у реальному часі.
Інтеграція з хмарними сервісами буде реалізована з використання хмарних сервісів, таких як Amazon Web Services (AWS) або Google Cloud Platform (GCP), для зберігання даних та аналітики.
Безпека даних буде реалізована за рахунок шифрування даних відповідно до стандартів безпеки, таких як TLS/SSL для захисту від несанкціонованого доступу та перехоплення даних.
"""

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-my-key-kn7iy63byGdeXiyxy5sXT3BlbkFJOCCZTOaP5OZydfIiRbaA")

completion = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {"role": "user", "content": "Сформуй документ System Design Specification , проаналізувавши інформацію: " + mobile_app_project + "документ має бути чітким та відповідати темі" }
  ]
)
print(completion.choices[0].message.content)
# Out:
# ## Документ: Технічна Специфікація Системи
# ### Назва Проекту: Розробка мобільного застосунку «Розумний будинок»
#
# #### 1. Введення
# ##### 1.1 Мета
# Мета проекту полягає у створенні мобільного застосунку "Розумний Будинок", який інтегрує управління всіма пристроями в домі через інтуїтивно зрозумілий інтерфейс, забезпечуючи ефективне, зручне та економічне управління домогосподарством.
#
# ##### 1.2 Об’єкт розробки
# Система "Розумний Будинок" та її компоненти: електротехніка, системи безпеки, камери спостереження та інші IoT пристрої.
#
# #### 2. Загальний опис
# ##### 2.1 Функції продукту
# - Інтуїтивно зрозумілий інтерфейс для управління усіма підключеними пристроями.
# - Розширені можливості за допомогою інтеграції з хмарними сервісами для аналітики і звітів.
# - Автоматичне виявлення та відповідь на події у домогосподарстві з використанням сценаріїв автоматизації та AI.
#
# ##### 2.2 Користувацькі характеристики
# ...
